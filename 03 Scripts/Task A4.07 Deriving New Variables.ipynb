# %% [markdown]
# # Task A4.07 Deriving New Variables

# %% [markdown]
# ### Table of Contents
# ##### 01. Import Libraries & dataframe creation
# ##### 02. Exercise 4.7 Practice: Creating columns
# ##### 03.  Busiest days column
# ##### 04. Busiest period of day

# %% [markdown]
# ### 01. Import Libraries & dataframe creation

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# path shortcut
path = r'/Users/nicolechiu/OneDrive - InterVarsity Christian Fellowship USA/Documents/CF Data Analytics/Achievement 4/05-2023 Instacart Basket Analysis'

# %%
# orders_products_merged dataframe creation 
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %% [markdown]
# ### 02. Exercise 4.7 Practice: Creating columns

# %%
# Creating subset of first 1,000,000 rows
df = df_ords_prods_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %%
# Define a function

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Apply the function
df['price range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/2x/7bz34nhx55b0cg_q5g2zvsn40000gn/T/ipykernel_1101/3940438240.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price range'] = df.apply(price_label, axis=1)

# %%
df['price range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %%
# Using loc 
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High range product'
# Out:
# /var/folders/2x/7bz34nhx55b0cg_q5g2zvsn40000gn/T/ipykernel_1101/3097742551.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid range product    756450
# Low range product    243550
# Name: price_range_loc, dtype: int64

# %%
# Using loc on entire df
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df_ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low range product'

# %%
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid range product     21860860
# Low range product     10126321
# High range product      417678
# Name: price_range_loc, dtype: int64

# %%
# Printing frequency of the orders day of the week column
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
# Create new column to detail busy-ness of the day 

result = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Combine new result with rest of df
df_ords_prods_merged['busiest_day'] = result

# %%
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# ### 03. Busiest days column

# %%
# Two busiest days are: Saturday '0' and Sunday '1'. The two slowest days are: Wednesday '4' and Tuesday '3'
# Create new column to detail two busiest and two slowest days

result2 = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if (value == 0) or (value ==1):
    result.append("Busiest days")
  elif (value == 4) or (value==3):
    result.append("Least busiest days")
  else:
    result.append("Regularly busy")

# %%
# Combine new result2 with rest of df
df_ords_prods_merged['busiest_days'] = result2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Combine new result2 with rest of df
# ----> 2 df_ords_prods_merged['busiest_days'] = result2
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
#    4177         key in self.columns
#    4178         and value.ndim == 1
# ...

# %%
rest2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 rest2
#
# NameError: name 'rest2' is not defined

# %%
# Typo... investigating result2
result2
# Out:
# []

# %%
# Two busiest days are: Saturday '0' and Sunday '1'. The two slowest days are: Wednesday '4' and Tuesday '3'
# Create new column to detail two busiest and two slowest days - renaming list, Attempt #2

busiest_days = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if (value == 0) or (value ==1):
    result.append("Busiest days")
  elif (value == 4) or (value==3):
    result.append("Least busiest days")
  else:
    result.append("Regularly busy")

# %%
busiest_days
# Out:
# []

# %%
# Two busiest days are: Saturday '0' and Sunday '1'. The two slowest days are: Wednesday '4' and Tuesday '3'
# Create new column to detail two busiest and two slowest days - removing parentheses, Attempt #3

busiest_days = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0 or value ==1:
    result.append("Busiest days")
  elif value == 4 or value==3:
    result.append("Least busiest days")
  else:
    result.append("Regularly busy")

# %%
busiest_days
# Out:
# []

# %%
# Investigating df
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
# Two busiest days are: Saturday '0' and Sunday '1'. The two slowest days are: Wednesday '4' and Tuesday '3'
# Create new column to detail two busiest and two slowest days - I cannot type, Attempt #4

busiest_days = []

for value in df_ords_prods_merged['orders_day_of_week']:
  if value == 0 or value == 1:
    result.append('Busiest days')
  elif value == 4 or value == 3:
    result.append('Least busiest days')
  else:
    result.append('Regularly busy')

# %%
busiest_days
# Out:
# []

# %%
# Two busiest days are: Saturday '0' and Sunday '1'. The two slowest days are: Wednesday '4' and Tuesday '3'
# Create new column to detail two busiest and two slowest days - STILL cannot type, Attempt #5

busiest_days = []

for value in df_ords_prods_merged['orders_day_of_week']:
  if value == 0 or value == 1:
    busiest_days.append('Busiest days')
  elif value == 4 or value == 3:
    busiest_days.append('Least busiest days')
  else:
    busiest_days.append('Regularly busy')

# %%
busiest_days
# Out:
# ['Regularly busy',
#  'Least busiest days',
#  'Least busiest days',
#  'Least busiest days',
#  'Least busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Least busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busiest days',
#  'Least busiest days',
#  'Least busiest days',
#  'Least busiest days',
#  'Least busiest days',
#  'Least busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busiest days',
#  'Regularly busy',
#  'Least busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Least busiest days',
#  'Least busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
# ...

# %%
# Create busiest_days column
df_ords_prods_merged['busiest_days'] = busiest_days

# %%
# Check frequency 
df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy        12916111
# Busiest days          11864412
# Least busiest days     7624336
# Name: busiest_days, dtype: int64

# %%
# Cross checking new busiest days column with frequency of the orders day of the week column

# %%
# Top 2 busiest days (0 and 1) add up to 11864412
# Least 2 busiest days (3 and 4) add up to 7624336
# Hooray

# %% [markdown]
# ### 04. Busiest period of day

# %%
# Printing frequency of the orders hour of day column
df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
# Since we are looking at a 24 hour day and wanting to split into 3 timeframes, would have 8 hours in each time frame, as such:
# 'Most orders' = 10, 11, 14, 15, 13, 12, 16, 9
# 'Average orders' = 17, 8, 18, 19, 20, 7, 21, 22
# 'Fewest orders' = 23, 6, 0, 1, 5, 2, 4, 3

# %%
# Create new column to detail busiest hours of the day 

hours = []

for value in df_ords_prods_merged['order_hour_of_day']:
  if value in [10, 11, 14, 15, 13, 12, 16, 9]:
    hours.append('Most orders')
  elif value in [23, 6, 0, 1, 5, 2, 4, 3]:
    hours.append('Fewest orders')
  else:
    hours.append('Average orders')

# %%
# Create busiest_period_of_day column
df_ords_prods_merged['busiest_period_of_day'] = hours

# %%
# Check frequency 
df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: busiest_period_of_day, dtype: int64

# %%
# Export inner merge df to orders_products_merged pkl
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_task_4_7.pkl'))
